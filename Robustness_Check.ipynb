# %%
import pandas as pd
import statsmodels.formula.api as smf

# %%
# Read Low-cost Airline Data
try:
    data_lowcost = pd.read_csv('low_cost_robust.csv', encoding='utf-8')
except UnicodeDecodeError:
    data_lowcost = pd.read_csv('low_cost_robust.csv', encoding='ISO-8859-1')
    
data_lowcost.head()
# Out:
#              status aircraft     travel_type   travel_class  \
# 0     Not Verified       NaN        Business  Economy Class
# 1     Not Verified      A320        Business  Economy Class
# 2  ? Trip Verified   A320NEO    Solo Leisure  Economy Class
# 3     Not Verified      A320  Couple Leisure  Economy Class
# 4  ? Trip Verified       NaN    Solo Leisure  Economy Class
#
#                          route    date  seating_comfort  staff_service  \
# 0   London Gatwick to Bordeaux  24-Jun              2.0            2.0
# 1         Bristol to Edinburgh  24-May              1.0            1.0
# 2  Porto to Ajaccio via Geneva  24-May              3.0            4.0
# 3          Gatwick to Tenerife  24-May              2.0            5.0
# 4          Hurghada to Gatwick  24-May              1.0            1.0
#
#    food_quality  entertainment  ...  value_for_money  recommended  \
# 0           NaN            NaN  ...                1           no
# ...

# %%
#Linear regression analysis： Low-cost 
#covid_19+company_age+log_company_size+log_net_profit
model = smf.ols(formula='watson_score~seating_comfort+staff_service+ground_service+value_for_money+covid_19+company_age+log_company_size+log_net_profit', data=data_lowcost)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           watson_score   R-squared:                       0.643
# Model:                            OLS   Adj. R-squared:                  0.642
# Method:                 Least Squares   F-statistic:                     509.5
# Date:                Tue, 20 Aug 2024   Prob (F-statistic):               0.00
# Time:                        05:35:49   Log-Likelihood:                -758.94
# No. Observations:                2273   AIC:                             1536.
# Df Residuals:                    2264   BIC:                             1587.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -1.4482      0.124    -11.641      0.000      -1.692      -1.204
# ...

# %%
#Read Traditional Airline Data
try:
    data_traditional = pd.read_csv('traditional_robust.csv', encoding='utf-8')
except UnicodeDecodeError:
    data_traditional = pd.read_csv('traditional_robust.csv', encoding='ISO-8859-1')
    
data_traditional.head()
# Out:
#              status                 aircraft     travel_type     travel_class  \
# 0  ? Trip Verified                Boeing 777  Family Leisure  Premium Economy
# 1  ? Trip Verified                       NaN    Solo Leisure    Economy Class
# 2  ? Trip Verified                       NaN    Solo Leisure    Economy Class
# 3  ? Trip Verified   A321 / Boeing 777-300ER  Couple Leisure    Economy Class
# 4  ? Trip Verified                       NaN  Family Leisure    Economy Class
#
#                                 route    date  seating_comfort  staff_service  \
# 0                    Paris to Toronto  24-Jul              2.0            1.0
# 1                   New York to Paris  24-Jan              1.0            1.0
# 2      Hamburg to Singapore via Paris  24-Jul              1.0            1.0
# 3       Lisbon to Singapore via Paris  24-Jul              4.0            2.0
# 4  Los Angeles to Barcelona via Paris  24-Jul              3.0            2.0
#
# ...

# %%
#Linear regression analysis: traditional 
#covid_19+company_age+log_company_size+log_net_profit
model_2 = smf.ols(formula='watson_score~seating_comfort+staff_service+ground_service+value_for_money+covid_19+company_age+log_company_size+log_net_profit', data=data_traditional)
results = model_2.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           watson_score   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     535.7
# Date:                Tue, 20 Aug 2024   Prob (F-statistic):               0.00
# Time:                        05:35:58   Log-Likelihood:                -935.08
# No. Observations:                2245   AIC:                             1888.
# Df Residuals:                    2236   BIC:                             1940.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.8225      0.167     -4.932      0.000      -1.150      -0.495
# ...
