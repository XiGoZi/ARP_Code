# %%
import pandas as pd

# %%
# Read Low-cost Airline data
try:
    data_lowcost = pd.read_csv('low_cost.csv', encoding='utf-8')
except UnicodeDecodeError:
    data_lowcost = pd.read_csv('low_cost.csv', encoding='ISO-8859-1')
    
data_lowcost.head()
# Out:
#              status aircraft     travel_type   travel_class  \
# 0     Not Verified       NaN        Business  Economy Class
# 1     Not Verified      A320        Business  Economy Class
# 2  ? Trip Verified   A320NEO    Solo Leisure  Economy Class
# 3     Not Verified      A320  Couple Leisure  Economy Class
# 4  ? Trip Verified       NaN    Solo Leisure  Economy Class
#
#                          route    date  seating_comfort  staff_service  \
# 0   London Gatwick to Bordeaux  24-Jun              2.0            2.0
# 1         Bristol to Edinburgh  24-May              1.0            1.0
# 2  Porto to Ajaccio via Geneva  24-May              3.0            4.0
# 3          Gatwick to Tenerife  24-May              2.0            5.0
# 4          Hurghada to Gatwick  24-May              1.0            1.0
#
#    food_quality  entertainment  ...  value_for_money  recommended  \
# 0           NaN            NaN  ...              1.0           no
# ...

# %%
#Descriptive statistics of Low-cost Airline
data_lowcost[['seating_comfort', 'staff_service', 'ground_service', 'value_for_money', 'watson_score', 'company_age', 'log_company_size', 'log_net_profit']].describe()
# Out:
#        seating_comfort  staff_service  ground_service  value_for_money  \
# count      2658.000000    2637.000000     2821.000000      2999.000000
# mean          2.086531       2.424346        1.846508         2.090363
# std           1.268313       1.522487        1.382071         1.510085
# min           1.000000       1.000000        1.000000         1.000000
# 25%           1.000000       1.000000        1.000000         1.000000
# 50%           2.000000       2.000000        1.000000         1.000000
# 75%           3.000000       4.000000        2.000000         3.000000
# max           5.000000       5.000000        5.000000         5.000000
#
#        watson_score  company_age  log_company_size  log_net_profit
# count   3000.000000  3000.000000       3000.000000     3000.000000
# mean      -0.520072    26.356667          8.328710        2.310457
# std        0.538852     7.907062          0.771764        5.772254
# ...

# %%
#Low-cost Airline Data Distribution
import matplotlib.pyplot as plt

#Sentiment Data Distribution#
val_count = data_lowcost.watson_sentiment.value_counts()

plt.figure(figsize=(8,4))
plt.bar(val_count.index, val_count.values, color='blue')

bars = plt.bar(val_count.index, val_count.values)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom')
    
plt.title("Low-cost Airline Data Distribution")
# Out:
# Text(0.5, 1.0, 'Low-cost Airline Data Distribution')

# %%
# Read Traditional Airline
try:
    data_traditional = pd.read_csv('traditional.csv', encoding='utf-8')
except UnicodeDecodeError:
    data_traditional = pd.read_csv('traditional.csv', encoding='ISO-8859-1')
    
data_traditional.head()
# Out:
#              status                 aircraft     travel_type     travel_class  \
# 0  ? Trip Verified                Boeing 777  Family Leisure  Premium Economy
# 1  ? Trip Verified                       NaN    Solo Leisure    Economy Class
# 2  ? Trip Verified                       NaN    Solo Leisure    Economy Class
# 3  ? Trip Verified   A321 / Boeing 777-300ER  Couple Leisure    Economy Class
# 4  ? Trip Verified                       NaN  Family Leisure    Economy Class
#
#                                 route    date  seating_comfort  staff_service  \
# 0                    Paris to Toronto  24-Jul              2.0            1.0
# 1                   New York to Paris  24-Jan              1.0            1.0
# 2      Hamburg to Singapore via Paris  24-Jul              1.0            1.0
# 3       Lisbon to Singapore via Paris  24-Jul              4.0            2.0
# 4  Los Angeles to Barcelona via Paris  24-Jul              3.0            2.0
#
# ...

# %%
#Descriptive statistics of Traditional Airline
data_traditional[['seating_comfort', 'staff_service', 'ground_service', 'value_for_money', 'watson_score', 'company_age', 'log_company_size', 'log_net_profit']].describe()
# Out:
#        seating_comfort  staff_service  ground_service  value_for_money  \
# count      2778.000000    2761.000000     2859.000000      3000.000000
# mean          2.715983       3.080768        2.499825         2.390667
# std           1.372726       1.546031        1.543939         1.502708
# min           1.000000       1.000000        1.000000         1.000000
# 25%           1.000000       1.000000        1.000000         1.000000
# 50%           3.000000       3.000000        2.000000         2.000000
# 75%           4.000000       5.000000        4.000000         4.000000
# max           5.000000       5.000000        5.000000         5.000000
#
#        watson_score  company_age  log_company_size  log_net_profit
# count   3000.000000  3000.000000       3000.000000     3000.000000
# mean      -0.351686    67.344000          9.716825        4.240577
# std        0.645684    15.834706          0.560674        5.501779
# ...

# %%
#Traditional Airline Data Distribution
#Sentiment Data Distribution#
val_count_1 = data_traditional.watson_sentiment.value_counts()

plt.figure(figsize=(8,4))
plt.bar(val_count_1.index, val_count_1.values, color='blue')

bars = plt.bar(val_count_1.index, val_count_1.values)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom')
plt.title("Traditional Airlines Sentiment Data Distribution")
# Out:
# Text(0.5, 1.0, 'Traditional Airlines Sentiment Data Distribution')
